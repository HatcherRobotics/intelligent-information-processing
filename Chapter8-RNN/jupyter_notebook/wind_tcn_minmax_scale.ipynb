# %%
import pandas as pd
import numpy as np
import torch
import torch.utils.data as Data
import torch.nn.utils.weight_norm as weight_norm
import torch.nn as nn
from sklearn.metrics import mean_squared_error , mean_absolute_error #平均均方误差/平均绝对误差
from sklearn.preprocessing import MinMaxScaler
import math
import time
import matplotlib.pyplot as plt
from torch.nn import functional as F

# %%
# 定义dataset
class my_Dataset(Data.Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
class WindDataset:
    def __init__(self,predict_step=3,label=5):
        minmax_scaler = MinMaxScaler()
        raw_data = pd.read_excel("weather.xlsx")
        self.predict_step = predict_step
        self.label = label
        #归一化
        self.data = minmax_scaler.fit_transform(raw_data)
        self.min = minmax_scaler.data_min_[label]
        self.max = minmax_scaler.data_max_[label]

    def denormalize(self, x):
        x = x*(self.max-self.min)+self.min
        return x

    def construct_set(self, train_por=0.65,val_por=0.2,test_por=0.15, window_size=50):
        train_x = []
        train_y = []
        val_x = []
        val_y = []
        test_x = []
        test_y = []
        len_train = int(self.data.shape[0] * train_por)
        #print("len_train",len_train)
        len_val = int(self.data.shape[0] * val_por)
        len_test = int(self.data.shape[0] * test_por)
        train_seqs = self.data[:len_train,:]
        print(train_seqs.shape)
        val_seqs = self.data[len_train:len_val+len_train,:]
        print(val_seqs.shape)
        test_seqs = self.data[len_train+len_val:len_val+len_train+len_test,:]
        print(test_seqs.shape)

        for i in range(train_seqs.shape[0] - window_size-self.predict_step+1):
            train_seq = train_seqs[i:i+window_size+self.predict_step]
            train_x.append(train_seq[0:window_size,:])
            train_y.append(train_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(val_seqs.shape[0] - window_size-self.predict_step+1):
            val_seq = val_seqs[i:i+window_size+self.predict_step]
            val_x.append(val_seq[0:window_size,:])
            val_y.append(val_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(test_seqs.shape[0] - window_size-self.predict_step+1):
            test_seq = test_seqs[i:i+window_size+self.predict_step]
            test_x.append(test_seq[0:window_size,:])
            test_y.append(test_seq[window_size:window_size+self.predict_step,self.label])

        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y).squeeze())
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y).squeeze())
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y).squeeze())
        return train_set, val_set, test_set

# %%
WindData = WindDataset()
train_set, val_set, test_set = WindData.construct_set()
batch_size = 16
train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
# Out:
# (347, 19)
# (107, 19)
# (80, 19)

# %%
class Chomp1d(nn.Module):
    def __init__(self,chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = int(chomp_size)
    def forward(self,x):
        #print(self.chomp_size)
        return x[:,:,0:-self.chomp_size].contiguous()
#在padding与chomp浪费了大量时间为了使输出序列相等
class TCNResidualBlock(nn.Module):
    def __init__(self,inchannel,outchannel,kernelsize,dilation):
        super(TCNResidualBlock,self).__init__()
        self.ke = int(kernelsize+(kernelsize-1)*(dilation-1))
        self.conv = nn.Sequential(
            weight_norm(nn.Conv1d(inchannel,outchannel,kernel_size=kernelsize,dilation=dilation,padding=self.ke-1)),
            Chomp1d(self.ke-1),    
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
            weight_norm(nn.Conv1d(outchannel,outchannel,kernel_size=kernelsize,dilation=dilation,padding=self.ke-1)),
            Chomp1d(self.ke-1),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
        )
        self.conv1x1 = nn.Sequential( 
            weight_norm(nn.Conv1d(inchannel,outchannel,kernel_size=1)),
            )
        
    def forward(self,X):
        Y = self.conv(X)
        #print("Y:",Y.shape)
        X = self.conv1x1(X)
        #print("X:",X.shape)
        out = F.relu(X+Y)
        return out

# %%
#通道数是特征的意思
#input: batch_size * features * seq_length但数据集的输入是batch_size * seq_length * features
block1 = TCNResidualBlock(19,32,5,1)
block2 = TCNResidualBlock(32,16,5,2)
block3 = TCNResidualBlock(16,8,3,4)

class TCNet(nn.Module):
    def __init__(self,hidden_size,predict_step):
        super(TCNet,self).__init__()
        self.features = nn.Sequential(
            block1,block2,block3
        )
        self.flatten = nn.Flatten()
        self.regression = nn.Sequential(
            nn.Linear(hidden_size, hidden_size//2),
            nn.Dropout(p=0.2),
            nn.ReLU(),
            nn.Linear(hidden_size//2, predict_step),
            nn.LeakyReLU()
        )
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)
    def forward(self,X):
        X = X.permute(0,2,1).contiguous()
        features = self.features(X)
        #print("features:",features.shape)
        out = self.flatten(features)
        #out = F.avg_pool1d(features,features.shape[-1])
        #print("out:",out.shape)
        out = self.regression(out).squeeze()
        return out

# %%
device = torch.device("cuda")
input_size = train_set.X.shape[-1]
hidden_size = 400
output_size = 3
lr = 0.001
epochs = 160
loss = nn.MSELoss()
my_tcn = TCNet(hidden_size,output_size).to(device)
optimizer = torch.optim.Adam(my_tcn.parameters(), lr)

# %%
def mean_absolute_percentage_error(y, pred):
    mask = y != 0
    y = y[mask]
    pred = pred[mask]
    mape = np.abs((y - pred) / y)
    mape = np.mean(mape) * 100
    return mape


def eval(y, pred):
    y = y.cpu().numpy()
    pred = pred.cpu().numpy()
    mse = mean_squared_error(y, pred)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y, pred)
    mape = mean_absolute_percentage_error(y, pred)
    return [rmse, mae, mape]

# %%
def evaluate(net,data_iter, loss, denormalize_fn, device='cuda:0'):
    rmse, mae, mape = 0, 0, 0
    batch_count = 0
    total_loss = 0.0
    net.eval()
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        l = loss(y_hat, y.long())
        y = denormalize_fn(y)
        y_hat = denormalize_fn(y_hat)
        a, b, c = eval(y.detach(), y_hat.detach())
        rmse += a
        mae += b
        mape += c
        total_loss += l.detach().cpu().numpy().tolist()
        batch_count += 1
    return [rmse / batch_count, mae / batch_count, mape / batch_count], total_loss / batch_count

# %%
def train(net, train_iter, val_iter, test_iter, loss_fn, denormalize_fn, optimizer, num_epoch,device='cuda:0'):
    train_loss_lst = []
    val_loss_lst = []
    train_score_lst = []
    val_score_lst = []
    epoch_time = []
    for epoch in range(num_epoch):
        net.train()
        epoch_loss = 0
        batch_count = 0
        batch_time = []
        rmse, mae, mape = 0, 0, 0
        for X, Y in train_iter:
            #print("X:",X.shape)
            #print("Y:",Y.shape)
            batch_s = time.time()
            X = X.to(device).float()
            Y = Y.to(device).float()
            optimizer.zero_grad()
            y_hat = net(X).squeeze()
            #print("y_hat",y_hat.shape)
            #print("y_hat:",y_hat)
            #print("Y:",Y)
            loss = loss_fn(y_hat, Y)
            loss.backward()
            optimizer.step()

            Y = denormalize_fn(Y)
            y_hat = denormalize_fn(y_hat)
            a, b, c = eval(Y.detach(), y_hat.detach())
            rmse += a
            mae += b
            mape += c
            epoch_loss += loss.detach().cpu().numpy().tolist()
            batch_count += 1

            batch_time.append(time.time() - batch_s)

        train_loss = epoch_loss / batch_count
        train_loss_lst.append(train_loss)
        train_score_lst.append([rmse/batch_count, mae/batch_count, mape/batch_count])

        # 验证集
        val_score, val_loss = evaluate(net, val_iter, loss_fn, denormalize_fn, device)
        val_score_lst.append(val_score)
        val_loss_lst.append(val_loss)

        epoch_time.append(np.array(batch_time).sum())
        print('*** epoch%d, train loss %.8f, train rmse %.4f, val loss %.8f, val rmse %.6f, time use %.3fs' %(epoch + 1, train_loss, train_score_lst[-1][0], val_loss, val_score[0], epoch_time[-1]))

    # 输出最终训练结果
    print(f'\n{"*" * 40}\nFinal result:')
    print(f'Total time {np.array(epoch_time).sum():.2f}s')

    # 计算测试集效果
    test_score, test_loss = evaluate(net,test_iter, loss_fn, denormalize_fn, device)
    print('Test result:')
    print(f'Test RMSE: {test_score[0]}    Test MAE: {test_score[1]}    Test MAPE: {test_score[2]}')
    return train_loss_lst, val_loss_lst, train_score_lst, val_score_lst

# %%
def visualization(train_loss,val_loss):
    x1=np.linspace(0,len(train_loss),len(train_loss))
    plt.plot(x1,train_loss,label='train_loss',linewidth=1.5)
    plt.plot(x1,val_loss,label='test_loss',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

def plot_metric(score_log):
    score_log = np.array(score_log)

    plt.figure(figsize=(10, 6), dpi=300)
    plt.subplot(2, 2, 1)
    plt.plot(score_log[:, 0], c='#d28ad4')
    plt.ylabel('RMSE')

    plt.subplot(2, 2, 2)
    plt.plot(score_log[:, 1], c='#e765eb')
    plt.ylabel('MAE')

    plt.subplot(2, 2, 3)
    plt.plot(score_log[:, 2], c='#6b016d')
    plt.ylabel('MAPE')

    plt.show()

# %%
train_loss_lst, val_loss_lst, train_score_lst, val_score_lst = train(my_tcn, train_loader, val_loader, test_loader,loss, WindData.denormalize, optimizer, epochs,device=device)
# Out:
# *** epoch1, train loss 0.07268028, train rmse 3.6530, val loss 0.10354423, val rmse 2.382613, time use 0.320s
# *** epoch2, train loss 0.05621208, train rmse 3.2069, val loss 0.05831039, val rmse 1.659349, time use 0.256s
# *** epoch3, train loss 0.04181550, train rmse 2.7799, val loss 0.08506387, val rmse 2.040762, time use 0.246s
# *** epoch4, train loss 0.03952878, train rmse 2.7099, val loss 0.05339754, val rmse 1.590153, time use 0.247s
# *** epoch5, train loss 0.03478270, train rmse 2.5163, val loss 0.05374345, val rmse 1.618634, time use 0.246s
# *** epoch6, train loss 0.03074716, train rmse 2.3829, val loss 0.05410843, val rmse 1.625526, time use 0.243s
# *** epoch7, train loss 0.02948263, train rmse 2.3211, val loss 0.03473564, val rmse 1.409905, time use 0.266s
# *** epoch8, train loss 0.02641943, train rmse 2.1926, val loss 0.03316152, val rmse 1.169967, time use 0.252s
# *** epoch9, train loss 0.02655336, train rmse 2.2142, val loss 0.03345126, val rmse 0.965541, time use 0.301s
# *** epoch10, train loss 0.02256497, train rmse 2.0207, val loss 0.03146595, val rmse 0.680141, time use 0.222s
# *** epoch11, train loss 0.02104818, train rmse 1.9578, val loss 0.03187690, val rmse 0.668711, time use 0.259s
# *** epoch12, train loss 0.02011012, train rmse 1.9205, val loss 0.06121393, val rmse 1.081256, time use 0.248s
# *** epoch13, train loss 0.01999506, train rmse 1.9162, val loss 0.03536128, val rmse 0.688116, time use 0.252s
# *** epoch14, train loss 0.01761277, train rmse 1.7914, val loss 0.02195355, val rmse 0.887401, time use 0.250s
# *** epoch15, train loss 0.01694381, train rmse 1.7591, val loss 0.04331720, val rmse 0.735895, time use 0.243s
# *** epoch16, train loss 0.01632606, train rmse 1.7211, val loss 0.04306414, val rmse 0.722758, time use 0.238s
# *** epoch17, train loss 0.01628183, train rmse 1.7087, val loss 0.03309624, val rmse 0.639868, time use 0.257s
# *** epoch18, train loss 0.01469065, train rmse 1.6352, val loss 0.03624815, val rmse 0.622715, time use 0.242s
# *** epoch19, train loss 0.01473759, train rmse 1.6326, val loss 0.04742347, val rmse 0.785850, time use 0.267s
# *** epoch20, train loss 0.01473294, train rmse 1.6346, val loss 0.04875371, val rmse 0.784988, time use 0.285s
# *** epoch21, train loss 0.01441938, train rmse 1.6172, val loss 0.02172564, val rmse 0.814559, time use 0.246s
# *** epoch22, train loss 0.01378978, train rmse 1.5884, val loss 0.03659828, val rmse 0.659739, time use 0.240s
# *** epoch23, train loss 0.01241008, train rmse 1.5049, val loss 0.04397151, val rmse 0.713326, time use 0.269s
# *** epoch24, train loss 0.01130706, train rmse 1.4300, val loss 0.03212042, val rmse 0.616991, time use 0.272s
# *** epoch25, train loss 0.01158956, train rmse 1.4532, val loss 0.02889940, val rmse 0.629308, time use 0.316s
# *** epoch26, train loss 0.01239130, train rmse 1.4940, val loss 0.04075050, val rmse 0.632470, time use 0.263s
# *** epoch27, train loss 0.01197382, train rmse 1.4679, val loss 0.04581676, val rmse 0.710360, time use 0.265s
# *** epoch28, train loss 0.00956470, train rmse 1.3266, val loss 0.03477774, val rmse 0.615596, time use 0.244s
# *** epoch29, train loss 0.01081138, train rmse 1.3994, val loss 0.03986467, val rmse 0.626051, time use 0.267s
# *** epoch30, train loss 0.00964376, train rmse 1.3180, val loss 0.03612226, val rmse 0.627056, time use 0.249s
# *** epoch31, train loss 0.00980787, train rmse 1.3258, val loss 0.03797860, val rmse 0.671215, time use 0.253s
# *** epoch32, train loss 0.01478829, train rmse 1.6334, val loss 0.03637347, val rmse 0.648633, time use 0.254s
# *** epoch33, train loss 0.01057114, train rmse 1.3961, val loss 0.03764703, val rmse 0.591009, time use 0.242s
# *** epoch34, train loss 0.00939218, train rmse 1.2953, val loss 0.03321906, val rmse 0.608139, time use 0.278s
# *** epoch35, train loss 0.00879131, train rmse 1.2590, val loss 0.03917827, val rmse 0.660518, time use 0.250s
# *** epoch36, train loss 0.00899626, train rmse 1.2846, val loss 0.03700530, val rmse 0.611823, time use 0.243s
# *** epoch37, train loss 0.00884119, train rmse 1.2710, val loss 0.03206252, val rmse 0.602849, time use 0.241s
# *** epoch38, train loss 0.00765290, train rmse 1.1813, val loss 0.03261390, val rmse 0.643680, time use 0.265s
# *** epoch39, train loss 0.00782373, train rmse 1.1915, val loss 0.03550087, val rmse 0.596204, time use 0.273s
# *** epoch40, train loss 0.00710769, train rmse 1.1332, val loss 0.03752491, val rmse 0.612902, time use 0.267s
# *** epoch41, train loss 0.00832343, train rmse 1.2329, val loss 0.02747474, val rmse 0.707464, time use 0.260s
# *** epoch42, train loss 0.00772809, train rmse 1.1935, val loss 0.02775143, val rmse 0.652276, time use 0.279s
# *** epoch43, train loss 0.00763067, train rmse 1.1764, val loss 0.03736108, val rmse 0.594726, time use 0.257s
# *** epoch44, train loss 0.00802345, train rmse 1.2064, val loss 0.03606588, val rmse 0.591300, time use 0.253s
# *** epoch45, train loss 0.00813159, train rmse 1.2196, val loss 0.04360332, val rmse 0.683049, time use 0.257s
# *** epoch46, train loss 0.00711851, train rmse 1.1307, val loss 0.04077180, val rmse 0.664296, time use 0.248s
# *** epoch47, train loss 0.00783832, train rmse 1.2034, val loss 0.03455957, val rmse 0.630698, time use 0.258s
# *** epoch48, train loss 0.00695306, train rmse 1.1261, val loss 0.03358730, val rmse 0.670780, time use 0.251s
# *** epoch49, train loss 0.00571439, train rmse 1.0283, val loss 0.03988932, val rmse 0.641780, time use 0.260s
# *** epoch50, train loss 0.00566116, train rmse 1.0228, val loss 0.02720405, val rmse 0.673620, time use 0.249s
# *** epoch51, train loss 0.00717818, train rmse 1.1431, val loss 0.03124224, val rmse 0.634731, time use 0.242s
# *** epoch52, train loss 0.00631715, train rmse 1.0779, val loss 0.03742711, val rmse 0.625992, time use 0.246s
# *** epoch53, train loss 0.00667286, train rmse 1.1055, val loss 0.03745753, val rmse 0.620212, time use 0.247s
# *** epoch54, train loss 0.00547422, train rmse 1.0031, val loss 0.03062142, val rmse 0.651837, time use 0.253s
# *** epoch55, train loss 0.00623723, train rmse 1.0665, val loss 0.03222472, val rmse 0.665225, time use 0.244s
# *** epoch56, train loss 0.00582722, train rmse 1.0241, val loss 0.04131379, val rmse 0.671733, time use 0.275s
# *** epoch57, train loss 0.00540491, train rmse 0.9961, val loss 0.03694104, val rmse 0.616924, time use 0.252s
# *** epoch58, train loss 0.00523522, train rmse 0.9795, val loss 0.03595726, val rmse 0.627870, time use 0.297s
# *** epoch59, train loss 0.00593126, train rmse 1.0339, val loss 0.04555300, val rmse 0.722916, time use 0.244s
# *** epoch60, train loss 0.00600857, train rmse 1.0503, val loss 0.03735013, val rmse 0.602807, time use 0.250s
# *** epoch61, train loss 0.00559458, train rmse 0.9977, val loss 0.03584258, val rmse 0.598147, time use 0.306s
# *** epoch62, train loss 0.00547268, train rmse 1.0042, val loss 0.03571238, val rmse 0.636512, time use 0.244s
# *** epoch63, train loss 0.00527287, train rmse 0.9885, val loss 0.03127076, val rmse 0.646380, time use 0.272s
# *** epoch64, train loss 0.00507839, train rmse 0.9641, val loss 0.03181770, val rmse 0.580435, time use 0.249s
# *** epoch65, train loss 0.00499223, train rmse 0.9568, val loss 0.03156817, val rmse 0.637056, time use 0.264s
# *** epoch66, train loss 0.00518550, train rmse 0.9742, val loss 0.03746136, val rmse 0.621296, time use 0.267s
# *** epoch67, train loss 0.00522982, train rmse 0.9699, val loss 0.04319687, val rmse 0.664320, time use 0.259s
# *** epoch68, train loss 0.00529118, train rmse 0.9713, val loss 0.04289147, val rmse 0.671132, time use 0.252s
# *** epoch69, train loss 0.00521691, train rmse 0.9762, val loss 0.03818080, val rmse 0.622115, time use 0.248s
# *** epoch70, train loss 0.00504113, train rmse 0.9637, val loss 0.03333623, val rmse 0.585654, time use 0.250s
# *** epoch71, train loss 0.00419313, train rmse 0.8781, val loss 0.03268466, val rmse 0.603906, time use 0.269s
# *** epoch72, train loss 0.00448512, train rmse 0.9110, val loss 0.03718032, val rmse 0.595821, time use 0.255s
# *** epoch73, train loss 0.00482786, train rmse 0.9397, val loss 0.03552467, val rmse 0.602107, time use 0.256s
# *** epoch74, train loss 0.00451101, train rmse 0.9128, val loss 0.04483013, val rmse 0.681532, time use 0.246s
# *** epoch75, train loss 0.00486722, train rmse 0.9404, val loss 0.03253964, val rmse 0.592354, time use 0.305s
# *** epoch76, train loss 0.00426793, train rmse 0.8834, val loss 0.03661010, val rmse 0.587122, time use 0.241s
# *** epoch77, train loss 0.00439159, train rmse 0.8999, val loss 0.03780081, val rmse 0.584060, time use 0.304s
# *** epoch78, train loss 0.00392418, train rmse 0.8489, val loss 0.03762030, val rmse 0.580243, time use 0.267s
# *** epoch79, train loss 0.00389654, train rmse 0.8439, val loss 0.03756428, val rmse 0.590580, time use 0.245s
# *** epoch80, train loss 0.00419285, train rmse 0.8726, val loss 0.03759883, val rmse 0.593037, time use 0.254s
# *** epoch81, train loss 0.00440861, train rmse 0.8980, val loss 0.03497539, val rmse 0.570128, time use 0.255s
# *** epoch82, train loss 0.00426334, train rmse 0.8832, val loss 0.03097344, val rmse 0.636576, time use 0.314s
# *** epoch83, train loss 0.00411766, train rmse 0.8613, val loss 0.03230129, val rmse 0.581845, time use 0.253s
# *** epoch84, train loss 0.00424041, train rmse 0.8759, val loss 0.03120240, val rmse 0.606482, time use 0.257s
# *** epoch85, train loss 0.00394857, train rmse 0.8526, val loss 0.03295929, val rmse 0.600513, time use 0.262s
# *** epoch86, train loss 0.00382223, train rmse 0.8420, val loss 0.03788324, val rmse 0.577196, time use 0.266s
# *** epoch87, train loss 0.00354982, train rmse 0.8083, val loss 0.04239532, val rmse 0.633212, time use 0.294s
# *** epoch88, train loss 0.00397324, train rmse 0.8576, val loss 0.03758022, val rmse 0.574423, time use 0.261s
# *** epoch89, train loss 0.00337992, train rmse 0.7847, val loss 0.03814575, val rmse 0.598450, time use 0.258s
# *** epoch90, train loss 0.00367485, train rmse 0.8203, val loss 0.04568720, val rmse 0.689381, time use 0.245s
# *** epoch91, train loss 0.00380276, train rmse 0.8374, val loss 0.04015840, val rmse 0.608634, time use 0.255s
# *** epoch92, train loss 0.00353536, train rmse 0.8055, val loss 0.03765693, val rmse 0.557440, time use 0.256s
# *** epoch93, train loss 0.00364581, train rmse 0.8138, val loss 0.04073049, val rmse 0.606279, time use 0.263s
# *** epoch94, train loss 0.00370601, train rmse 0.8212, val loss 0.03813798, val rmse 0.591800, time use 0.270s
# *** epoch95, train loss 0.00369074, train rmse 0.8240, val loss 0.03114919, val rmse 0.620357, time use 0.310s
# *** epoch96, train loss 0.00327555, train rmse 0.7772, val loss 0.03989150, val rmse 0.589280, time use 0.286s
# *** epoch97, train loss 0.00336536, train rmse 0.7845, val loss 0.03451099, val rmse 0.570726, time use 0.250s
# *** epoch98, train loss 0.00332212, train rmse 0.7807, val loss 0.04044376, val rmse 0.600714, time use 0.241s
# *** epoch99, train loss 0.00312705, train rmse 0.7597, val loss 0.03755371, val rmse 0.575000, time use 0.281s
# *** epoch100, train loss 0.00328064, train rmse 0.7715, val loss 0.04363340, val rmse 0.660893, time use 0.246s
# *** epoch101, train loss 0.00364733, train rmse 0.8186, val loss 0.04413047, val rmse 0.683252, time use 0.256s
# *** epoch102, train loss 0.00355245, train rmse 0.8050, val loss 0.03739047, val rmse 0.591901, time use 0.249s
# *** epoch103, train loss 0.00327779, train rmse 0.7738, val loss 0.03673022, val rmse 0.575195, time use 0.261s
# *** epoch104, train loss 0.00329880, train rmse 0.7733, val loss 0.03545235, val rmse 0.590685, time use 0.320s
# *** epoch105, train loss 0.00306177, train rmse 0.7482, val loss 0.03722132, val rmse 0.592919, time use 0.274s
# *** epoch106, train loss 0.00290390, train rmse 0.7291, val loss 0.03857295, val rmse 0.599725, time use 0.259s
# *** epoch107, train loss 0.00289608, train rmse 0.7290, val loss 0.03846695, val rmse 0.586389, time use 0.266s
# *** epoch108, train loss 0.00288955, train rmse 0.7266, val loss 0.03776008, val rmse 0.565775, time use 0.276s
# *** epoch109, train loss 0.00279334, train rmse 0.7182, val loss 0.03761525, val rmse 0.574985, time use 0.268s
# *** epoch110, train loss 0.00309002, train rmse 0.7536, val loss 0.04394381, val rmse 0.664406, time use 0.248s
# *** epoch111, train loss 0.00323835, train rmse 0.7712, val loss 0.03674855, val rmse 0.565038, time use 0.243s
# *** epoch112, train loss 0.00274831, train rmse 0.7119, val loss 0.03124302, val rmse 0.613853, time use 0.259s
# *** epoch113, train loss 0.00270712, train rmse 0.7054, val loss 0.03333653, val rmse 0.616946, time use 0.254s
# *** epoch114, train loss 0.00277952, train rmse 0.7147, val loss 0.03498126, val rmse 0.580757, time use 0.248s
# *** epoch115, train loss 0.00284369, train rmse 0.7214, val loss 0.03898772, val rmse 0.575373, time use 0.248s
# *** epoch116, train loss 0.00287229, train rmse 0.7259, val loss 0.03701309, val rmse 0.563659, time use 0.254s
# *** epoch117, train loss 0.00271040, train rmse 0.7006, val loss 0.03407620, val rmse 0.577684, time use 0.251s
# *** epoch118, train loss 0.00267970, train rmse 0.7011, val loss 0.03569251, val rmse 0.582680, time use 0.255s
# *** epoch119, train loss 0.00272426, train rmse 0.7089, val loss 0.04030032, val rmse 0.593098, time use 0.255s
# *** epoch120, train loss 0.00286531, train rmse 0.7162, val loss 0.03081158, val rmse 0.665467, time use 0.240s
# *** epoch121, train loss 0.00278676, train rmse 0.7148, val loss 0.03756669, val rmse 0.588531, time use 0.252s
# *** epoch122, train loss 0.00256312, train rmse 0.6842, val loss 0.04316255, val rmse 0.650485, time use 0.259s
# *** epoch123, train loss 0.00267836, train rmse 0.7015, val loss 0.03464970, val rmse 0.571946, time use 0.274s
# *** epoch124, train loss 0.00264569, train rmse 0.6958, val loss 0.02841171, val rmse 0.685415, time use 0.261s
# *** epoch125, train loss 0.00281329, train rmse 0.7104, val loss 0.03432618, val rmse 0.582942, time use 0.275s
# *** epoch126, train loss 0.00303133, train rmse 0.7436, val loss 0.03744116, val rmse 0.579460, time use 0.261s
# *** epoch127, train loss 0.00240840, train rmse 0.6686, val loss 0.03904854, val rmse 0.584641, time use 0.247s
# *** epoch128, train loss 0.00255574, train rmse 0.6814, val loss 0.03875478, val rmse 0.594242, time use 0.246s
# *** epoch129, train loss 0.00241017, train rmse 0.6611, val loss 0.03553191, val rmse 0.590219, time use 0.258s
# *** epoch130, train loss 0.00239108, train rmse 0.6618, val loss 0.03504316, val rmse 0.586826, time use 0.252s
# *** epoch131, train loss 0.00273466, train rmse 0.7024, val loss 0.03844027, val rmse 0.587052, time use 0.252s
# *** epoch132, train loss 0.00254553, train rmse 0.6764, val loss 0.03446399, val rmse 0.594610, time use 0.256s
# *** epoch133, train loss 0.00226815, train rmse 0.6411, val loss 0.04032771, val rmse 0.628856, time use 0.287s
# *** epoch134, train loss 0.00225735, train rmse 0.6463, val loss 0.03958442, val rmse 0.615364, time use 0.287s
# *** epoch135, train loss 0.00260520, train rmse 0.6882, val loss 0.03665220, val rmse 0.579576, time use 0.250s
# *** epoch136, train loss 0.00268222, train rmse 0.6957, val loss 0.03611443, val rmse 0.602161, time use 0.267s
# *** epoch137, train loss 0.00234025, train rmse 0.6501, val loss 0.03927521, val rmse 0.631455, time use 0.285s
# *** epoch138, train loss 0.00253178, train rmse 0.6802, val loss 0.04128978, val rmse 0.629887, time use 0.252s
# *** epoch139, train loss 0.00268600, train rmse 0.6929, val loss 0.03349805, val rmse 0.585902, time use 0.262s
# *** epoch140, train loss 0.00277727, train rmse 0.7020, val loss 0.03483329, val rmse 0.613150, time use 0.253s
# *** epoch141, train loss 0.00244767, train rmse 0.6672, val loss 0.03964717, val rmse 0.583052, time use 0.276s
# *** epoch142, train loss 0.00212271, train rmse 0.6260, val loss 0.03925709, val rmse 0.600031, time use 0.307s
# *** epoch143, train loss 0.00206858, train rmse 0.6060, val loss 0.03330578, val rmse 0.575287, time use 0.243s
# *** epoch144, train loss 0.00224038, train rmse 0.6324, val loss 0.03977960, val rmse 0.585594, time use 0.247s
# *** epoch145, train loss 0.00276476, train rmse 0.7026, val loss 0.04144046, val rmse 0.612020, time use 0.253s
# *** epoch146, train loss 0.00229139, train rmse 0.6463, val loss 0.03809908, val rmse 0.584648, time use 0.241s
# *** epoch147, train loss 0.00253572, train rmse 0.6684, val loss 0.03397163, val rmse 0.581234, time use 0.269s
# *** epoch148, train loss 0.00217243, train rmse 0.6259, val loss 0.04195227, val rmse 0.616080, time use 0.240s
# *** epoch149, train loss 0.00226422, train rmse 0.6435, val loss 0.03993188, val rmse 0.586810, time use 0.277s
# *** epoch150, train loss 0.00270571, train rmse 0.6967, val loss 0.03056616, val rmse 0.661839, time use 0.255s
# *** epoch151, train loss 0.00244281, train rmse 0.6644, val loss 0.03600626, val rmse 0.576101, time use 0.255s
# *** epoch152, train loss 0.00205508, train rmse 0.6046, val loss 0.03654574, val rmse 0.563401, time use 0.252s
# *** epoch153, train loss 0.00223267, train rmse 0.6330, val loss 0.03798350, val rmse 0.574586, time use 0.276s
# *** epoch154, train loss 0.00200175, train rmse 0.6064, val loss 0.03871589, val rmse 0.579632, time use 0.295s
# *** epoch155, train loss 0.00187734, train rmse 0.5876, val loss 0.03437892, val rmse 0.588643, time use 0.226s
# *** epoch156, train loss 0.00225264, train rmse 0.6358, val loss 0.03737072, val rmse 0.561724, time use 0.243s
# *** epoch157, train loss 0.00195408, train rmse 0.5982, val loss 0.04105577, val rmse 0.598586, time use 0.265s
# *** epoch158, train loss 0.00195287, train rmse 0.5923, val loss 0.03822219, val rmse 0.610308, time use 0.279s
# *** epoch159, train loss 0.00200893, train rmse 0.6039, val loss 0.03604767, val rmse 0.578409, time use 0.272s
# *** epoch160, train loss 0.00177515, train rmse 0.5690, val loss 0.03372998, val rmse 0.563005, time use 0.248s
#
# ****************************************
# Final result:
# Total time 41.67s
# Test result:
# Test RMSE: 2.9587482824026456    Test MAE: 2.588508367538452    Test MAPE: 32.5937956571579

# %%
#RMSE和样本有关，RMSE大表示预测值和理论值的差值也大
visualization(train_loss_lst, val_loss_lst)
plot_metric(train_score_lst)

# %%
train_loader = Data.DataLoader(train_set, batch_size=1, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)

# %%
def time_series_visualize(net,test_iter,denormalize_fn,num_epoch):
    net.eval()
    y_predict = []
    y_true = []
    for epoch in range(num_epoch):
        for x,y in test_iter:
            y_hat = net(x.to(device)).squeeze()
            y_hat = denormalize_fn(y_hat).detach().cpu().numpy()
            y = denormalize_fn(y)
            y_true.append(y.detach().numpy())
            y_predict.append(y_hat)
    y_predict = np.array(y_predict).squeeze()# epoch batch feature 28X3
    print("y_predict:",y_predict.shape)
    y_true = np.array(y_true).squeeze() # 28X3
    print("y_true:",y_true.shape)
    x1 = np.linspace(1,y_predict.shape[0],y_predict.shape[0])
    print("x1:",x1.shape)
    for j in range(y_predict.shape[-1]):    
        plt.plot(x1,y_predict[:,j],label='predict')
        plt.plot(x1,y_true[:,j],label='truth')
        plt.xlabel("time")
        plt.ylabel("wind")
        plt.legend()
        plt.show()
time_series_visualize(my_tcn,train_loader,WindData.denormalize,1)
# Out:
# y_predict: (295, 3)
# y_true: (295, 3)
# x1: (295,)

# %%
time_series_visualize(my_tcn,val_loader,WindData.denormalize,1)
# Out:
# y_predict: (55, 3)
# y_true: (55, 3)
# x1: (55,)

# %%
time_series_visualize(my_tcn,test_loader,WindData.denormalize,1)
# Out:
# y_predict: (28, 3)
# y_true: (28, 3)
# x1: (28,)
