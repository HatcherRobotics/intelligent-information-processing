# %%
import pandas as pd
import numpy as np
import torch
import torch.utils.data as Data
import torch.nn.utils.weight_norm as weight_norm
import torch.nn as nn
from sklearn.metrics import mean_squared_error , mean_absolute_error #平均均方误差/平均绝对误差
from sklearn.preprocessing import StandardScaler
import math
import time
import matplotlib.pyplot as plt
import numpy as np
from torch.nn import functional as F

# %%
# 定义dataset
class my_Dataset(Data.Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
class WindDataset:
    def __init__(self,predict_step=3,label=5):
        standard_scaler = StandardScaler()
        raw_data = pd.read_excel("weather.xlsx")
        self.predict_step = predict_step
        self.label = label
        #标准化
        self.data = standard_scaler.fit_transform(raw_data)
        self.mean = standard_scaler.mean_[label]
        self.sd = math.sqrt(standard_scaler.var_[label])

    def denormalize(self, x):
        x = x*self.sd+self.mean
        return x

    def construct_set(self, train_por=0.65,val_por=0.2,test_por=0.15, window_size=50):
        train_x = []
        train_y = []
        val_x = []
        val_y = []
        test_x = []
        test_y = []
        len_train = int(self.data.shape[0] * train_por)
        #print("len_train",len_train)
        len_val = int(self.data.shape[0] * val_por)
        len_test = int(self.data.shape[0] * test_por)
        train_seqs = self.data[:len_train,:]
        print(train_seqs.shape)
        val_seqs = self.data[len_train:len_val+len_train,:]
        print(val_seqs.shape)
        test_seqs = self.data[len_train+len_val:len_val+len_train+len_test,:]
        print(test_seqs.shape)

        for i in range(train_seqs.shape[0] - window_size-self.predict_step+1):
            train_seq = train_seqs[i:i+window_size+self.predict_step]
            train_x.append(train_seq[0:window_size,:])
            train_y.append(train_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(val_seqs.shape[0] - window_size-self.predict_step+1):
            val_seq = val_seqs[i:i+window_size+self.predict_step]
            val_x.append(val_seq[0:window_size,:])
            val_y.append(val_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(test_seqs.shape[0] - window_size-self.predict_step+1):
            test_seq = test_seqs[i:i+window_size+self.predict_step]
            test_x.append(test_seq[0:window_size,:])
            test_y.append(test_seq[window_size:window_size+self.predict_step,self.label])

        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y).squeeze())
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y).squeeze())
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y).squeeze())
        return train_set, val_set, test_set

# %%
WindData = WindDataset()
train_set, val_set, test_set = WindData.construct_set()
batch_size = 16
train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
# Out:
# (347, 19)
# (107, 19)
# (80, 19)

# %%
class Chomp1d(nn.Module):
    def __init__(self,chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = int(chomp_size)
    def forward(self,x):
        #print(self.chomp_size)
        return x[:,:,0:-self.chomp_size].contiguous()
#在padding与chomp浪费了大量时间为了使输出序列相等
class TCNResidualBlock(nn.Module):
    def __init__(self,inchannel,outchannel,kernelsize,dilation):
        super(TCNResidualBlock,self).__init__()
        self.ke = int(kernelsize+(kernelsize-1)*(dilation-1))
        self.conv = nn.Sequential(
            weight_norm(nn.Conv1d(inchannel,outchannel,kernel_size=kernelsize,dilation=dilation,padding=self.ke-1)),
            Chomp1d(self.ke-1),    
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
            weight_norm(nn.Conv1d(outchannel,outchannel,kernel_size=kernelsize,dilation=dilation,padding=self.ke-1)),
            Chomp1d(self.ke-1),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.2),
        )
        self.conv1x1 = nn.Sequential( 
            weight_norm(nn.Conv1d(inchannel,outchannel,kernel_size=1)),
            )
        
    def forward(self,X):
        Y = self.conv(X)
        #print("Y:",Y.shape)
        X = self.conv1x1(X)
        #print("X:",X.shape)
        out = F.relu(X+Y)
        return out

# %%
#通道数是特征的意思
#input: batch_size * features * seq_length但数据集的输入是batch_size * seq_length * features
block1 = TCNResidualBlock(19,32,5,1)
block2 = TCNResidualBlock(32,16,5,2)
block3 = TCNResidualBlock(16,8,3,4)

class TCNet(nn.Module):
    def __init__(self,hidden_size,predict_step):
        super(TCNet,self).__init__()
        self.features = nn.Sequential(
            block1,block2,block3
        )
        self.flatten = nn.Flatten()
        self.regression = nn.Sequential(
            nn.Linear(hidden_size, hidden_size//2),
            nn.Dropout(p=0.2),
            nn.ReLU(),
            nn.Linear(hidden_size//2, predict_step),
            nn.LeakyReLU()
        )
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)
    def forward(self,X):
        X = X.permute(0,2,1).contiguous()
        features = self.features(X)
        #print("features:",features.shape)
        out = self.flatten(features)
        #out = F.avg_pool1d(features,features.shape[-1])
        #print("out:",out.shape)
        out = self.regression(out).squeeze()
        return out

# %%
device = torch.device("cuda")
input_size = train_set.X.shape[-1]
hidden_size = 400
output_size = 3
lr = 0.001
epochs = 160
loss = nn.MSELoss()
my_tcn = TCNet(hidden_size,output_size).to(device)
optimizer = torch.optim.Adam(my_tcn.parameters(), lr)

# %%
def mean_absolute_percentage_error(y, pred):
    mask = y != 0
    y = y[mask]
    pred = pred[mask]
    mape = np.abs((y - pred) / y)
    mape = np.mean(mape) * 100
    return mape


def eval(y, pred):
    y = y.cpu().numpy()
    pred = pred.cpu().numpy()
    mse = mean_squared_error(y, pred)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y, pred)
    mape = mean_absolute_percentage_error(y, pred)
    return [rmse, mae, mape]

# %%
def evaluate(net,data_iter, loss, denormalize_fn, device='cuda:0'):
    rmse, mae, mape = 0, 0, 0
    batch_count = 0
    total_loss = 0.0
    net.eval()
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        l = loss(y_hat, y.long())
        y = denormalize_fn(y)
        y_hat = denormalize_fn(y_hat)
        a, b, c = eval(y.detach(), y_hat.detach())
        rmse += a
        mae += b
        mape += c
        total_loss += l.detach().cpu().numpy().tolist()
        batch_count += 1
    return [rmse / batch_count, mae / batch_count, mape / batch_count], total_loss / batch_count

# %%
def train(net, train_iter, val_iter, test_iter, loss_fn, denormalize_fn, optimizer, num_epoch,device='cuda:0'):
    train_loss_lst = []
    val_loss_lst = []
    train_score_lst = []
    val_score_lst = []
    epoch_time = []
    for epoch in range(num_epoch):
        net.train()
        epoch_loss = 0
        batch_count = 0
        batch_time = []
        rmse, mae, mape = 0, 0, 0
        for X, Y in train_iter:
            #print("X:",X.shape)
            #print("Y:",Y.shape)
            batch_s = time.time()
            X = X.to(device).float()
            Y = Y.to(device).float()
            optimizer.zero_grad()
            y_hat = net(X).squeeze()
            #print("y_hat",y_hat.shape)
            #print("y_hat:",y_hat)
            #print("Y:",Y)
            loss = loss_fn(y_hat, Y)
            loss.backward()
            optimizer.step()

            Y = denormalize_fn(Y)
            y_hat = denormalize_fn(y_hat)
            a, b, c = eval(Y.detach(), y_hat.detach())
            rmse += a
            mae += b
            mape += c
            epoch_loss += loss.detach().cpu().numpy().tolist()
            batch_count += 1

            batch_time.append(time.time() - batch_s)

        train_loss = epoch_loss / batch_count
        train_loss_lst.append(train_loss)
        train_score_lst.append([rmse/batch_count, mae/batch_count, mape/batch_count])

        # 验证集
        val_score, val_loss = evaluate(net, val_iter, loss_fn, denormalize_fn, device)
        val_score_lst.append(val_score)
        val_loss_lst.append(val_loss)

        epoch_time.append(np.array(batch_time).sum())
        print('*** epoch%d, train loss %.8f, train rmse %.4f, val loss %.8f, val rmse %.6f, time use %.3fs' %(epoch + 1, train_loss, train_score_lst[-1][0], val_loss, val_score[0], epoch_time[-1]))

    # 输出最终训练结果
    print(f'\n{"*" * 40}\nFinal result:')
    print(f'Total time {np.array(epoch_time).sum():.2f}s')

    # 计算测试集效果
    test_score, test_loss = evaluate(net,test_iter, loss_fn, denormalize_fn, device)
    print('Test result:')
    print(f'Test RMSE: {test_score[0]}    Test MAE: {test_score[1]}    Test MAPE: {test_score[2]}')
    return train_loss_lst, val_loss_lst, train_score_lst, val_score_lst

# %%
def visualization(train_loss,val_loss):
    x1=np.linspace(0,len(train_loss),len(train_loss))
    plt.plot(x1,train_loss,label='train_loss',linewidth=1.5)
    plt.plot(x1,val_loss,label='test_loss',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

def plot_metric(score_log):
    score_log = np.array(score_log)

    plt.figure(figsize=(10, 6), dpi=300)
    plt.subplot(2, 2, 1)
    plt.plot(score_log[:, 0], c='#d28ad4')
    plt.ylabel('RMSE')

    plt.subplot(2, 2, 2)
    plt.plot(score_log[:, 1], c='#e765eb')
    plt.ylabel('MAE')

    plt.subplot(2, 2, 3)
    plt.plot(score_log[:, 2], c='#6b016d')
    plt.ylabel('MAPE')

    plt.show()

# %%
train_loss_lst, val_loss_lst, train_score_lst, val_score_lst = train(my_tcn, train_loader, val_loader, test_loader,loss, WindData.denormalize, optimizer, epochs,device=device)
# Out:
# *** epoch1, train loss 1.22645166, train rmse 3.1754, val loss 0.24782170, val rmse 2.043022, time use 0.314s
# *** epoch2, train loss 1.19790522, train rmse 3.1493, val loss 0.30205166, val rmse 2.247944, time use 0.253s
# *** epoch3, train loss 1.13654414, train rmse 3.0588, val loss 0.26414138, val rmse 2.127199, time use 0.267s
# *** epoch4, train loss 1.02669172, train rmse 2.9328, val loss 0.24523313, val rmse 2.032201, time use 0.244s
# *** epoch5, train loss 0.81082297, train rmse 2.6078, val loss 0.24496480, val rmse 2.030994, time use 0.252s
# *** epoch6, train loss 0.64221828, train rmse 2.3176, val loss 0.24396533, val rmse 2.025827, time use 0.257s
# *** epoch7, train loss 0.60902116, train rmse 2.2720, val loss 0.24606867, val rmse 2.034698, time use 0.256s
# *** epoch8, train loss 0.58972239, train rmse 2.2355, val loss 0.24353681, val rmse 2.023482, time use 0.238s
# *** epoch9, train loss 0.58429961, train rmse 2.2235, val loss 0.24460908, val rmse 2.027827, time use 0.267s
# *** epoch10, train loss 0.56279266, train rmse 2.1812, val loss 0.24106566, val rmse 2.011762, time use 0.258s
# *** epoch11, train loss 0.55681049, train rmse 2.1664, val loss 0.23878102, val rmse 2.001117, time use 0.269s
# *** epoch12, train loss 0.55526539, train rmse 2.1632, val loss 0.23831898, val rmse 1.998279, time use 0.314s
# *** epoch13, train loss 0.52627863, train rmse 2.1025, val loss 0.22604274, val rmse 1.938075, time use 0.255s
# *** epoch14, train loss 0.49519667, train rmse 2.0467, val loss 0.20532769, val rmse 1.819160, time use 0.263s
# *** epoch15, train loss 0.43785465, train rmse 1.9188, val loss 0.20089044, val rmse 1.359088, time use 0.258s
# *** epoch16, train loss 0.37869239, train rmse 1.7818, val loss 0.36729108, val rmse 0.979614, time use 0.291s
# *** epoch17, train loss 0.35090844, train rmse 1.7135, val loss 0.35490254, val rmse 0.845122, time use 0.249s
# *** epoch18, train loss 0.34357525, train rmse 1.6891, val loss 0.27569746, val rmse 0.795678, time use 0.303s
# *** epoch19, train loss 0.31014580, train rmse 1.6048, val loss 0.27224166, val rmse 0.754778, time use 0.266s
# *** epoch20, train loss 0.30544875, train rmse 1.6014, val loss 0.28087136, val rmse 0.732104, time use 0.253s
# *** epoch21, train loss 0.30294731, train rmse 1.5976, val loss 0.24848793, val rmse 0.722436, time use 0.270s
# *** epoch22, train loss 0.27674189, train rmse 1.5169, val loss 0.32613526, val rmse 0.723297, time use 0.255s
# *** epoch23, train loss 0.26742834, train rmse 1.4923, val loss 0.28417266, val rmse 0.713488, time use 0.266s
# *** epoch24, train loss 0.25833190, train rmse 1.4757, val loss 0.20532739, val rmse 0.769814, time use 0.301s
# *** epoch25, train loss 0.26887106, train rmse 1.5062, val loss 0.31848567, val rmse 0.689721, time use 0.264s
# *** epoch26, train loss 0.23954227, train rmse 1.4202, val loss 0.29774962, val rmse 0.663725, time use 0.244s
# *** epoch27, train loss 0.25473284, train rmse 1.4644, val loss 0.27799775, val rmse 0.659261, time use 0.242s
# *** epoch28, train loss 0.24082270, train rmse 1.4171, val loss 0.25633419, val rmse 0.687531, time use 0.235s
# *** epoch29, train loss 0.25412986, train rmse 1.4559, val loss 0.27417380, val rmse 0.676949, time use 0.263s
# *** epoch30, train loss 0.25118560, train rmse 1.4566, val loss 0.26509156, val rmse 0.676694, time use 0.292s
# *** epoch31, train loss 0.25169626, train rmse 1.4505, val loss 0.30124295, val rmse 0.642548, time use 0.291s
# *** epoch32, train loss 0.24609855, train rmse 1.4391, val loss 0.27002174, val rmse 0.658593, time use 0.299s
# *** epoch33, train loss 0.22945405, train rmse 1.3855, val loss 0.24068121, val rmse 0.667831, time use 0.242s
# *** epoch34, train loss 0.22791365, train rmse 1.3770, val loss 0.22542844, val rmse 0.689953, time use 0.236s
# *** epoch35, train loss 0.22703330, train rmse 1.3756, val loss 0.34083573, val rmse 0.666585, time use 0.243s
# *** epoch36, train loss 0.22766529, train rmse 1.3862, val loss 0.23083797, val rmse 0.659477, time use 0.255s
# *** epoch37, train loss 0.22038081, train rmse 1.3640, val loss 0.37537453, val rmse 0.695281, time use 0.274s
# *** epoch38, train loss 0.21945543, train rmse 1.3601, val loss 0.22366624, val rmse 0.708923, time use 0.296s
# *** epoch39, train loss 0.22171835, train rmse 1.3682, val loss 0.26682347, val rmse 0.635275, time use 0.266s
# *** epoch40, train loss 0.21496058, train rmse 1.3399, val loss 0.27500160, val rmse 0.624061, time use 0.295s
# *** epoch41, train loss 0.21401886, train rmse 1.3177, val loss 0.23658474, val rmse 0.668514, time use 0.296s
# *** epoch42, train loss 0.21095720, train rmse 1.3248, val loss 0.30130044, val rmse 0.621354, time use 0.267s
# *** epoch43, train loss 0.21264892, train rmse 1.3208, val loss 0.24804842, val rmse 0.653728, time use 0.241s
# *** epoch44, train loss 0.21181682, train rmse 1.3262, val loss 0.27288492, val rmse 0.645047, time use 0.257s
# *** epoch45, train loss 0.21518875, train rmse 1.3430, val loss 0.26234328, val rmse 0.628894, time use 0.271s
# *** epoch46, train loss 0.20423920, train rmse 1.3054, val loss 0.21801476, val rmse 0.688084, time use 0.274s
# *** epoch47, train loss 0.20798769, train rmse 1.3192, val loss 0.31613320, val rmse 0.617554, time use 0.310s
# *** epoch48, train loss 0.20649491, train rmse 1.3140, val loss 0.30032670, val rmse 0.597561, time use 0.295s
# *** epoch49, train loss 0.20651264, train rmse 1.3185, val loss 0.33173675, val rmse 0.620529, time use 0.287s
# *** epoch50, train loss 0.20024750, train rmse 1.2898, val loss 0.25882940, val rmse 0.617597, time use 0.304s
# *** epoch51, train loss 0.20397653, train rmse 1.3084, val loss 0.35958241, val rmse 0.682542, time use 0.274s
# *** epoch52, train loss 0.21433085, train rmse 1.3265, val loss 0.24737610, val rmse 0.660695, time use 0.277s
# *** epoch53, train loss 0.20676617, train rmse 1.3201, val loss 0.30625168, val rmse 0.598538, time use 0.300s
# *** epoch54, train loss 0.19938131, train rmse 1.2905, val loss 0.24611831, val rmse 0.626010, time use 0.271s
# *** epoch55, train loss 0.20287827, train rmse 1.2986, val loss 0.31888734, val rmse 0.622675, time use 0.304s
# *** epoch56, train loss 0.19022380, train rmse 1.2583, val loss 0.22613809, val rmse 0.684461, time use 0.256s
# *** epoch57, train loss 0.19916889, train rmse 1.2874, val loss 0.30863197, val rmse 0.608337, time use 0.309s
# *** epoch58, train loss 0.19928206, train rmse 1.2916, val loss 0.25443346, val rmse 0.651069, time use 0.296s
# *** epoch59, train loss 0.20060372, train rmse 1.2916, val loss 0.27588741, val rmse 0.628371, time use 0.235s
# *** epoch60, train loss 0.18995195, train rmse 1.2485, val loss 0.30146385, val rmse 0.614019, time use 0.240s
# *** epoch61, train loss 0.19163393, train rmse 1.2643, val loss 0.31225782, val rmse 0.607090, time use 0.226s
# *** epoch62, train loss 0.19392603, train rmse 1.2637, val loss 0.27605840, val rmse 0.620632, time use 0.279s
# *** epoch63, train loss 0.18776162, train rmse 1.2483, val loss 0.27601769, val rmse 0.627322, time use 0.280s
# *** epoch64, train loss 0.18833424, train rmse 1.2455, val loss 0.27111181, val rmse 0.634230, time use 0.285s
# *** epoch65, train loss 0.18197496, train rmse 1.2284, val loss 0.30123876, val rmse 0.609773, time use 0.251s
# *** epoch66, train loss 0.17951129, train rmse 1.2142, val loss 0.28454583, val rmse 0.621189, time use 0.267s
# *** epoch67, train loss 0.17717727, train rmse 1.2108, val loss 0.25372929, val rmse 0.664192, time use 0.272s
# *** epoch68, train loss 0.18069726, train rmse 1.2254, val loss 0.31512078, val rmse 0.609626, time use 0.244s
# *** epoch69, train loss 0.17433898, train rmse 1.2012, val loss 0.29818777, val rmse 0.610002, time use 0.262s
# *** epoch70, train loss 0.16505082, train rmse 1.1617, val loss 0.31184773, val rmse 0.681869, time use 0.244s
# *** epoch71, train loss 0.17442046, train rmse 1.1971, val loss 0.37808912, val rmse 0.618274, time use 0.249s
# *** epoch72, train loss 0.16553502, train rmse 1.1631, val loss 0.29464662, val rmse 0.601635, time use 0.272s
# *** epoch73, train loss 0.15556645, train rmse 1.1326, val loss 0.21830274, val rmse 0.693645, time use 0.306s
# *** epoch74, train loss 0.15759269, train rmse 1.1469, val loss 0.31159030, val rmse 0.606018, time use 0.273s
# *** epoch75, train loss 0.15293306, train rmse 1.1193, val loss 0.27796969, val rmse 0.615382, time use 0.283s
# *** epoch76, train loss 0.15019520, train rmse 1.1099, val loss 0.28597491, val rmse 0.599881, time use 0.291s
# *** epoch77, train loss 0.14330888, train rmse 1.0809, val loss 0.29765280, val rmse 0.590051, time use 0.280s
# *** epoch78, train loss 0.15013878, train rmse 1.1237, val loss 0.26114143, val rmse 0.653053, time use 0.317s
# *** epoch79, train loss 0.13637184, train rmse 1.0668, val loss 0.27855951, val rmse 0.632566, time use 0.257s
# *** epoch80, train loss 0.14562661, train rmse 1.0873, val loss 0.30815532, val rmse 0.610772, time use 0.247s
# *** epoch81, train loss 0.13929580, train rmse 1.0764, val loss 0.28572451, val rmse 0.631996, time use 0.309s
# *** epoch82, train loss 0.14497177, train rmse 1.0925, val loss 0.28653164, val rmse 0.670081, time use 0.305s
# *** epoch83, train loss 0.14543827, train rmse 1.1012, val loss 0.37488022, val rmse 0.634231, time use 0.242s
# *** epoch84, train loss 0.13985280, train rmse 1.0690, val loss 0.29039919, val rmse 0.630708, time use 0.250s
# *** epoch85, train loss 0.14085237, train rmse 1.0779, val loss 0.28004832, val rmse 0.633955, time use 0.245s
# *** epoch86, train loss 0.13988706, train rmse 1.0761, val loss 0.35974824, val rmse 0.642395, time use 0.258s
# *** epoch87, train loss 0.13796264, train rmse 1.0675, val loss 0.27926115, val rmse 0.670439, time use 0.283s
# *** epoch88, train loss 0.13431775, train rmse 1.0464, val loss 0.30432008, val rmse 0.635873, time use 0.277s
# *** epoch89, train loss 0.12846392, train rmse 1.0251, val loss 0.27681074, val rmse 0.697587, time use 0.305s
# *** epoch90, train loss 0.12658873, train rmse 1.0224, val loss 0.28949354, val rmse 0.677366, time use 0.245s
# *** epoch91, train loss 0.13160762, train rmse 1.0441, val loss 0.37544848, val rmse 0.641968, time use 0.271s
# *** epoch92, train loss 0.12457808, train rmse 1.0167, val loss 0.29140753, val rmse 0.685541, time use 0.244s
# *** epoch93, train loss 0.12138916, train rmse 1.0070, val loss 0.33391474, val rmse 0.643365, time use 0.250s
# *** epoch94, train loss 0.12113191, train rmse 1.0020, val loss 0.28423338, val rmse 0.684626, time use 0.259s
# *** epoch95, train loss 0.12067758, train rmse 1.0025, val loss 0.33883701, val rmse 0.663973, time use 0.283s
# *** epoch96, train loss 0.11813487, train rmse 0.9837, val loss 0.29088182, val rmse 0.707896, time use 0.300s
# *** epoch97, train loss 0.12547881, train rmse 1.0170, val loss 0.30247818, val rmse 0.671823, time use 0.252s
# *** epoch98, train loss 0.11825295, train rmse 0.9851, val loss 0.27168653, val rmse 0.742291, time use 0.292s
# *** epoch99, train loss 0.12330010, train rmse 1.0130, val loss 0.25997058, val rmse 0.753007, time use 0.257s
# *** epoch100, train loss 0.11141418, train rmse 0.9679, val loss 0.33503336, val rmse 0.658725, time use 0.220s
# *** epoch101, train loss 0.11381948, train rmse 0.9698, val loss 0.30834334, val rmse 0.655326, time use 0.240s
# *** epoch102, train loss 0.10050336, train rmse 0.9175, val loss 0.28063766, val rmse 0.653319, time use 0.262s
# *** epoch103, train loss 0.10214374, train rmse 0.9224, val loss 0.31229659, val rmse 0.645491, time use 0.301s
# *** epoch104, train loss 0.09724229, train rmse 0.8977, val loss 0.30315899, val rmse 0.646897, time use 0.249s
# *** epoch105, train loss 0.09587219, train rmse 0.8968, val loss 0.26594683, val rmse 0.695164, time use 0.281s
# *** epoch106, train loss 0.09738815, train rmse 0.8997, val loss 0.34937864, val rmse 0.658284, time use 0.280s
# *** epoch107, train loss 0.10144935, train rmse 0.9243, val loss 0.30565022, val rmse 0.635611, time use 0.314s
# *** epoch108, train loss 0.10556396, train rmse 0.9423, val loss 0.28264813, val rmse 0.690935, time use 0.298s
# *** epoch109, train loss 0.09863061, train rmse 0.9108, val loss 0.23653595, val rmse 0.767490, time use 0.243s
# *** epoch110, train loss 0.08840627, train rmse 0.8587, val loss 0.33586642, val rmse 0.632946, time use 0.270s
# *** epoch111, train loss 0.09105618, train rmse 0.8678, val loss 0.28987538, val rmse 0.665047, time use 0.249s
# *** epoch112, train loss 0.08038590, train rmse 0.8210, val loss 0.29239318, val rmse 0.679641, time use 0.292s
# *** epoch113, train loss 0.08282738, train rmse 0.8362, val loss 0.27112931, val rmse 0.707594, time use 0.259s
# *** epoch114, train loss 0.08133579, train rmse 0.8269, val loss 0.27533216, val rmse 0.683635, time use 0.259s
# *** epoch115, train loss 0.08697377, train rmse 0.8570, val loss 0.24446143, val rmse 0.767800, time use 0.250s
# *** epoch116, train loss 0.09289314, train rmse 0.8857, val loss 0.25684817, val rmse 0.697052, time use 0.243s
# *** epoch117, train loss 0.08890289, train rmse 0.8655, val loss 0.27526796, val rmse 0.651023, time use 0.275s
# *** epoch118, train loss 0.08522784, train rmse 0.8480, val loss 0.35946468, val rmse 0.635335, time use 0.251s
# *** epoch119, train loss 0.08143378, train rmse 0.8237, val loss 0.22639274, val rmse 0.827271, time use 0.241s
# *** epoch120, train loss 0.07800269, train rmse 0.8080, val loss 0.29147525, val rmse 0.657816, time use 0.249s
# *** epoch121, train loss 0.07873573, train rmse 0.8121, val loss 0.27304772, val rmse 0.672879, time use 0.261s
# *** epoch122, train loss 0.07831402, train rmse 0.8134, val loss 0.30485600, val rmse 0.638945, time use 0.255s
# *** epoch123, train loss 0.07126319, train rmse 0.7752, val loss 0.26595489, val rmse 0.727285, time use 0.228s
# *** epoch124, train loss 0.07994283, train rmse 0.8166, val loss 0.32896812, val rmse 0.639548, time use 0.243s
# *** epoch125, train loss 0.07920033, train rmse 0.8096, val loss 0.32939746, val rmse 0.653549, time use 0.241s
# *** epoch126, train loss 0.07714120, train rmse 0.8038, val loss 0.31315851, val rmse 0.662217, time use 0.291s
# *** epoch127, train loss 0.07702990, train rmse 0.8069, val loss 0.27678791, val rmse 0.654621, time use 0.306s
# *** epoch128, train loss 0.06963535, train rmse 0.7651, val loss 0.26874156, val rmse 0.685171, time use 0.257s
# *** epoch129, train loss 0.07247734, train rmse 0.7779, val loss 0.25653636, val rmse 0.710882, time use 0.243s
# *** epoch130, train loss 0.06994665, train rmse 0.7676, val loss 0.35109452, val rmse 0.633040, time use 0.239s
# *** epoch131, train loss 0.07043768, train rmse 0.7702, val loss 0.25215409, val rmse 0.692061, time use 0.240s
# *** epoch132, train loss 0.06953604, train rmse 0.7643, val loss 0.32909429, val rmse 0.625017, time use 0.246s
# *** epoch133, train loss 0.07034795, train rmse 0.7715, val loss 0.30802497, val rmse 0.652653, time use 0.270s
# *** epoch134, train loss 0.06376682, train rmse 0.7316, val loss 0.27668497, val rmse 0.645568, time use 0.257s
# *** epoch135, train loss 0.06737785, train rmse 0.7519, val loss 0.27018544, val rmse 0.666896, time use 0.253s
# *** epoch136, train loss 0.07388356, train rmse 0.7895, val loss 0.25595781, val rmse 0.720935, time use 0.256s
# *** epoch137, train loss 0.06748691, train rmse 0.7543, val loss 0.25607583, val rmse 0.730420, time use 0.243s
# *** epoch138, train loss 0.06960807, train rmse 0.7631, val loss 0.32707895, val rmse 0.650457, time use 0.257s
# *** epoch139, train loss 0.06711567, train rmse 0.7477, val loss 0.27463302, val rmse 0.685224, time use 0.259s
# *** epoch140, train loss 0.06359840, train rmse 0.7265, val loss 0.30282407, val rmse 0.631609, time use 0.248s
# *** epoch141, train loss 0.06424296, train rmse 0.7323, val loss 0.30917272, val rmse 0.651543, time use 0.251s
# *** epoch142, train loss 0.06167131, train rmse 0.7184, val loss 0.25327578, val rmse 0.705308, time use 0.246s
# *** epoch143, train loss 0.06013055, train rmse 0.7088, val loss 0.29471361, val rmse 0.650074, time use 0.246s
# *** epoch144, train loss 0.06127711, train rmse 0.7159, val loss 0.28599824, val rmse 0.668776, time use 0.243s
# *** epoch145, train loss 0.06298969, train rmse 0.7194, val loss 0.29660637, val rmse 0.632979, time use 0.257s
# *** epoch146, train loss 0.06201368, train rmse 0.7168, val loss 0.23964367, val rmse 0.740754, time use 0.228s
# *** epoch147, train loss 0.06536957, train rmse 0.7412, val loss 0.32118592, val rmse 0.605236, time use 0.292s
# *** epoch148, train loss 0.06165890, train rmse 0.7213, val loss 0.28570977, val rmse 0.640511, time use 0.253s
# *** epoch149, train loss 0.06398390, train rmse 0.7339, val loss 0.29510443, val rmse 0.631487, time use 0.258s
# *** epoch150, train loss 0.06271522, train rmse 0.7277, val loss 0.25880364, val rmse 0.672684, time use 0.248s
# *** epoch151, train loss 0.06220630, train rmse 0.7235, val loss 0.29016906, val rmse 0.643270, time use 0.247s
# *** epoch152, train loss 0.05955455, train rmse 0.7018, val loss 0.25572752, val rmse 0.688769, time use 0.294s
# *** epoch153, train loss 0.06104909, train rmse 0.7166, val loss 0.24788278, val rmse 0.716537, time use 0.315s
# *** epoch154, train loss 0.06290236, train rmse 0.7287, val loss 0.33918079, val rmse 0.608327, time use 0.274s
# *** epoch155, train loss 0.05906177, train rmse 0.7028, val loss 0.27877979, val rmse 0.652472, time use 0.217s
# *** epoch156, train loss 0.05699146, train rmse 0.6896, val loss 0.32665138, val rmse 0.628775, time use 0.243s
# *** epoch157, train loss 0.06227328, train rmse 0.7208, val loss 0.25130495, val rmse 0.719994, time use 0.267s
# *** epoch158, train loss 0.06160268, train rmse 0.7206, val loss 0.29394214, val rmse 0.660468, time use 0.296s
# *** epoch159, train loss 0.06064094, train rmse 0.7124, val loss 0.29715162, val rmse 0.682965, time use 0.312s
# *** epoch160, train loss 0.05946916, train rmse 0.7046, val loss 0.27972875, val rmse 0.679878, time use 0.247s
#
# ****************************************
# Final result:
# Total time 42.59s
# Test result:
# Test RMSE: 6.710886341117575    Test MAE: 6.45556640625    Test MAPE: 86.65335774421692

# %%
#RMSE和样本有关，RMSE大表示预测值和理论值的差值也大
visualization(train_loss_lst, val_loss_lst)
plot_metric(train_score_lst)

# %%
train_loader = Data.DataLoader(train_set, batch_size=1, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)

# %%
def time_series_visualize(net,test_iter,denormalize_fn,num_epoch):
    net.eval()
    y_predict = []
    y_true = []
    for epoch in range(num_epoch):
        for x,y in test_iter:
            y_hat = net(x.to(device)).squeeze()
            y_hat = denormalize_fn(y_hat).detach().cpu().numpy()
            y = denormalize_fn(y)
            y_true.append(y.detach().numpy())
            y_predict.append(y_hat)
    y_predict = np.array(y_predict).squeeze()# epoch batch feature 28X3
    print("y_predict:",y_predict.shape)
    y_true = np.array(y_true).squeeze() # 28X3
    print("y_true:",y_true.shape)
    x1 = np.linspace(1,y_predict.shape[0],y_predict.shape[0])
    print("x1:",x1.shape)
    for j in range(y_predict.shape[-1]):    
        plt.plot(x1,y_predict[:,j],label='predict')
        plt.plot(x1,y_true[:,j],label='truth')
        plt.xlabel("time")
        plt.ylabel("wind")
        plt.legend()
        plt.show()
time_series_visualize(my_tcn,train_loader,WindData.denormalize,1)
# Out:
# y_predict: (295, 3)
# y_true: (295, 3)
# x1: (295,)

# %%
time_series_visualize(my_tcn,val_loader,WindData.denormalize,1)
# Out:
# y_predict: (55, 3)
# y_true: (55, 3)
# x1: (55,)

# %%
time_series_visualize(my_tcn,test_loader,WindData.denormalize,1)
# Out:
# y_predict: (28, 3)
# y_true: (28, 3)
# x1: (28,)
