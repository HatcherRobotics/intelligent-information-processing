# %%
import pandas as pd
import numpy as np
import torch
import torch.utils.data as Data
import torch.nn as nn
from sklearn.metrics import mean_squared_error , mean_absolute_error #平均均方误差/平均绝对误差
from sklearn.preprocessing import MinMaxScaler
import math
import time
import matplotlib.pyplot as plt
import numpy as np

# %%
# 定义dataset
class my_Dataset(Data.Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels

    def __getitem__(self, index):
        return self.X[index], self.y[index]

    def __len__(self):
        return self.X.shape[0]

# %%
class WindDataset:
    def __init__(self,predict_step=3,label=5):
        minmax_scaler = MinMaxScaler()
        raw_data = pd.read_excel("weather.xlsx")
        self.predict_step = predict_step
        self.label = label
        #归一化
        self.data = minmax_scaler.fit_transform(raw_data)
        self.min = minmax_scaler.data_min_[label]
        #print("min:",self.min)
        self.max = minmax_scaler.data_max_[label]

    def denormalize(self, x):
        x = x*(self.max-self.min)+self.min
        return x

    def construct_set(self, train_por=0.65,val_por=0.2,test_por=0.15, window_size=50):
        train_x = []
        train_y = []
        val_x = []
        val_y = []
        test_x = []
        test_y = []
        len_train = int(self.data.shape[0] * train_por)
        #print("len_train",len_train)
        len_val = int(self.data.shape[0] * val_por)
        len_test = int(self.data.shape[0] * test_por)
        train_seqs = self.data[:len_train,:]
        print(train_seqs.shape)
        val_seqs = self.data[len_train:len_val+len_train,:]
        print(val_seqs.shape)
        test_seqs = self.data[len_train+len_val:len_val+len_train+len_test,:]
        print(test_seqs.shape)

        for i in range(train_seqs.shape[0] - window_size-self.predict_step+1):
            train_seq = train_seqs[i:i+window_size+self.predict_step]
            train_x.append(train_seq[0:window_size,:])
            train_y.append(train_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(val_seqs.shape[0] - window_size-self.predict_step+1):
            val_seq = val_seqs[i:i+window_size+self.predict_step]
            val_x.append(val_seq[0:window_size,:])
            val_y.append(val_seq[window_size:window_size+self.predict_step,self.label])

        for i in range(test_seqs.shape[0] - window_size-self.predict_step+1):
            test_seq = test_seqs[i:i+window_size+self.predict_step]
            test_x.append(test_seq[0:window_size,:])
            test_y.append(test_seq[window_size:window_size+self.predict_step,self.label])

        train_set = my_Dataset(torch.Tensor(train_x), torch.Tensor(train_y).squeeze())
        val_set = my_Dataset(torch.Tensor(val_x), torch.Tensor(val_y).squeeze())
        test_set = my_Dataset(torch.Tensor(test_x), torch.Tensor(test_y).squeeze())
        return train_set, val_set, test_set

# %%
WindData = WindDataset()
train_set, val_set, test_set = WindData.construct_set()
batch_size = 16
train_loader = Data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=4, drop_last=True)
# Out:
# (347, 19)
# (107, 19)
# (80, 19)

# %%
#input_size – The number of expected features in the input x
# input  seq_len * batch_size*features 
class LSTMNet(nn.Module):
    def __init__(self,batch_size,input_size,hidden_size,output_size,num_layers,seq_len,device="cuda"):
        super().__init__()
        self.batch_size = batch_size
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.seq_len = seq_len
        self.lstm = nn.LSTM(input_size=input_size,hidden_size=hidden_size,num_layers=num_layers,batch_first=False)
        self.outlinear = nn.Sequential(
            nn.Linear(in_features=self.hidden_size,out_features=hidden_size//2),
            nn.LeakyReLU(),
            nn.Linear(in_features=hidden_size//2,out_features=self.output_size)
        )
        for param in self.parameters():
            if param.dim() > 1:
                nn.init.xavier_uniform_(param)        
    def forward(self,x):
        h,c = (torch.zeros(self.num_layers,self.seq_len,self.hidden_size).to(x.device) for _ in range(2))
        H,(h,c) = self.lstm(x,(h,c))
        #print(H.shape)
        out = H[:,-1,:].squeeze()
        out = self.outlinear(out)
        return out

# %%
device = torch.device("cuda")
input_size = train_set.X.shape[-1]
hidden_size = 256#8的倍数
output_size = 3
lr = 0.0001
epochs=80
num_layers = 3
seq_len = 50
loss = nn.MSELoss()
lstm = LSTMNet(batch_size,input_size,hidden_size,output_size,num_layers,seq_len).to(device)
optimizer = torch.optim.Adam(lstm.parameters(), lr)

# %%
#mean_absolute_percentage_error 平均绝对百分比误差
def mean_absolute_percentage_error(y, pred):
    mask = y != 0
    y = y[mask]
    pred = pred[mask]
    mape = np.abs((y - pred) / y)
    mape = np.mean(mape) * 100
    return mape


def eval(y, pred):
    y = y.cpu().numpy()
    pred = pred.cpu().numpy()
    mse = mean_squared_error(y, pred)
    rmse = math.sqrt(mse)
    mae = mean_absolute_error(y, pred)
    mape = mean_absolute_percentage_error(y, pred)
    return [rmse, mae, mape]

# %%
def evaluate(net,data_iter, loss, denormalize_fn, device='cuda:0'):
    rmse, mae, mape = 0, 0, 0
    batch_count = 0
    total_loss = 0.0
    net.eval()
    for X, y in data_iter:
        X = X.to(device)
        y = y.to(device)
        y_hat = net(X)
        l = loss(y_hat, y.long())
        y = denormalize_fn(y)
        y_hat = denormalize_fn(y_hat)
        a, b, c = eval(y.detach(), y_hat.detach())
        rmse += a
        mae += b
        mape += c
        total_loss += l.detach().cpu().numpy().tolist()
        batch_count += 1
    return [rmse / batch_count, mae / batch_count, mape / batch_count], total_loss / batch_count

# %%
def train(net, train_iter, val_iter, test_iter, loss_fn, denormalize_fn, optimizer, num_epoch,device='cuda:0'):
    train_loss_lst = []
    val_loss_lst = []
    train_score_lst = []
    val_score_lst = []
    epoch_time = []
    for epoch in range(num_epoch):
        net.train()
        epoch_loss = 0
        batch_count = 0
        batch_time = []
        rmse, mae, mape = 0, 0, 0
        for X, Y in train_iter:
            #print("X:",X.shape)
            #print("Y:",Y.shape)
            batch_s = time.time()
            X = X.to(device).float()
            Y = Y.to(device).float()
            optimizer.zero_grad()
            y_hat = net(X)
            #print("y_hat",y_hat.shape)
            #print("y_hat:",y_hat)
            #print("Y:",Y)
            loss = loss_fn(y_hat, Y)
            loss.backward()
            optimizer.step()

            Y = denormalize_fn(Y)
            y_hat = denormalize_fn(y_hat)
            a, b, c = eval(Y.detach(), y_hat.detach())
            rmse += a
            mae += b
            mape += c
            epoch_loss += loss.detach().cpu().numpy().tolist()
            batch_count += 1

            batch_time.append(time.time() - batch_s)

        train_loss = epoch_loss / batch_count
        train_loss_lst.append(train_loss)
        train_score_lst.append([rmse/batch_count, mae/batch_count, mape/batch_count])

        # 验证集
        val_score, val_loss = evaluate(net, val_iter, loss_fn, denormalize_fn, device)
        val_score_lst.append(val_score)
        val_loss_lst.append(val_loss)

        epoch_time.append(np.array(batch_time).sum())
        print('*** epoch%d, train loss %.8f, train rmse %.4f, val loss %.8f, val rmse %.6f, time use %.3fs' %(epoch + 1, train_loss, train_score_lst[-1][0], val_loss, val_score[0], epoch_time[-1]))

    # 输出最终训练结果
    print(f'\n{"*" * 40}\nFinal result:')
    print(f'Total time {np.array(epoch_time).sum():.2f}s')

    # 计算测试集效果
    test_score, test_loss = evaluate(net,test_iter, loss_fn, denormalize_fn, device)
    print('Test result:')
    print(f'Test RMSE: {test_score[0]}    Test MAE: {test_score[1]}    Test MAPE: {test_score[2]}')
    return train_loss_lst, val_loss_lst, train_score_lst, val_score_lst

# %%
def visualization(train_loss,val_loss):
    x1=np.linspace(0,len(train_loss),len(train_loss))
    plt.plot(x1,train_loss,label='train_loss',linewidth=1.5)
    plt.plot(x1,val_loss,label='test_loss',linewidth=1.5)
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

def plot_metric(score_log):
    score_log = np.array(score_log)

    plt.figure(figsize=(10, 6), dpi=300)
    plt.subplot(2, 2, 1)
    plt.plot(score_log[:, 0], c='#d28ad4')
    plt.ylabel('RMSE')

    plt.subplot(2, 2, 2)
    plt.plot(score_log[:, 1], c='#e765eb')
    plt.ylabel('MAE')

    plt.subplot(2, 2, 3)
    plt.plot(score_log[:, 2], c='#6b016d')
    plt.ylabel('MAPE')

    plt.show()

# %%
train_loss_lst, val_loss_lst, train_score_lst, val_score_lst = train(lstm, train_loader, val_loader, test_loader,loss, WindData.denormalize, optimizer,epochs,device=device)
# Out:
# *** epoch1, train loss 0.09555509, train rmse 4.1779, val loss 0.08573561, val rmse 2.259844, time use 0.176s
# *** epoch2, train loss 0.06358816, train rmse 3.4046, val loss 0.09146824, val rmse 2.247956, time use 0.157s
# *** epoch3, train loss 0.06062297, train rmse 3.3222, val loss 0.08406895, val rmse 2.060784, time use 0.137s
# *** epoch4, train loss 0.05949462, train rmse 3.2728, val loss 0.09671117, val rmse 2.262536, time use 0.134s
# *** epoch5, train loss 0.05095433, train rmse 3.0420, val loss 0.10070631, val rmse 2.317844, time use 0.137s
# *** epoch6, train loss 0.05535265, train rmse 3.1722, val loss 0.09963424, val rmse 2.281262, time use 0.140s
# *** epoch7, train loss 0.05537027, train rmse 3.1939, val loss 0.10448351, val rmse 2.374285, time use 0.134s
# *** epoch8, train loss 0.05715784, train rmse 3.2073, val loss 0.09363715, val rmse 2.149273, time use 0.148s
# *** epoch9, train loss 0.05549596, train rmse 3.1793, val loss 0.08965481, val rmse 2.058417, time use 0.130s
# *** epoch10, train loss 0.05395001, train rmse 3.1340, val loss 0.09598281, val rmse 2.180299, time use 0.157s
# *** epoch11, train loss 0.05351876, train rmse 3.1417, val loss 0.09370184, val rmse 2.133152, time use 0.139s
# *** epoch12, train loss 0.05475959, train rmse 3.1576, val loss 0.10563386, val rmse 2.369891, time use 0.141s
# *** epoch13, train loss 0.05519086, train rmse 3.1502, val loss 0.08909295, val rmse 2.033335, time use 0.153s
# *** epoch14, train loss 0.05104047, train rmse 3.0376, val loss 0.08149381, val rmse 1.880640, time use 0.151s
# *** epoch15, train loss 0.04908669, train rmse 3.0137, val loss 0.07391689, val rmse 1.737432, time use 0.134s
# *** epoch16, train loss 0.04683100, train rmse 2.9234, val loss 0.07664077, val rmse 1.768396, time use 0.152s
# *** epoch17, train loss 0.04154199, train rmse 2.7525, val loss 0.09281206, val rmse 2.084498, time use 0.155s
# *** epoch18, train loss 0.03400724, train rmse 2.4980, val loss 0.10766066, val rmse 2.393095, time use 0.138s
# *** epoch19, train loss 0.02771497, train rmse 2.2526, val loss 0.05502062, val rmse 1.411716, time use 0.136s
# *** epoch20, train loss 0.02044522, train rmse 1.9344, val loss 0.04399853, val rmse 1.249511, time use 0.137s
# *** epoch21, train loss 0.02008338, train rmse 1.9228, val loss 0.05364892, val rmse 1.340478, time use 0.133s
# *** epoch22, train loss 0.01710594, train rmse 1.7698, val loss 0.04235429, val rmse 1.205307, time use 0.137s
# *** epoch23, train loss 0.01732343, train rmse 1.7864, val loss 0.02179073, val rmse 1.144789, time use 0.144s
# *** epoch24, train loss 0.01851963, train rmse 1.8404, val loss 0.03535213, val rmse 1.155343, time use 0.134s
# *** epoch25, train loss 0.01677248, train rmse 1.7489, val loss 0.04212619, val rmse 1.175418, time use 0.138s
# *** epoch26, train loss 0.01667721, train rmse 1.7506, val loss 0.05268122, val rmse 1.300241, time use 0.146s
# *** epoch27, train loss 0.01820169, train rmse 1.8235, val loss 0.03523044, val rmse 1.100372, time use 0.157s
# *** epoch28, train loss 0.01648300, train rmse 1.7427, val loss 0.04416401, val rmse 1.152940, time use 0.129s
# *** epoch29, train loss 0.01693112, train rmse 1.7653, val loss 0.04532000, val rmse 1.146071, time use 0.139s
# *** epoch30, train loss 0.01552736, train rmse 1.6626, val loss 0.04216103, val rmse 1.105813, time use 0.156s
# *** epoch31, train loss 0.01507085, train rmse 1.6451, val loss 0.04831807, val rmse 1.181328, time use 0.130s
# *** epoch32, train loss 0.01551601, train rmse 1.6857, val loss 0.04649351, val rmse 1.156677, time use 0.133s
# *** epoch33, train loss 0.01528504, train rmse 1.6721, val loss 0.03586675, val rmse 1.068813, time use 0.174s
# *** epoch34, train loss 0.01503954, train rmse 1.6597, val loss 0.04316515, val rmse 1.107309, time use 0.143s
# *** epoch35, train loss 0.01432674, train rmse 1.6260, val loss 0.04147406, val rmse 1.082490, time use 0.147s
# *** epoch36, train loss 0.01515740, train rmse 1.6523, val loss 0.04306587, val rmse 1.101726, time use 0.141s
# *** epoch37, train loss 0.01399010, train rmse 1.6049, val loss 0.03162540, val rmse 1.025982, time use 0.157s
# *** epoch38, train loss 0.01570029, train rmse 1.6949, val loss 0.03895011, val rmse 1.057382, time use 0.136s
# *** epoch39, train loss 0.01450562, train rmse 1.6115, val loss 0.05579132, val rmse 1.290732, time use 0.135s
# *** epoch40, train loss 0.01482898, train rmse 1.6451, val loss 0.04062332, val rmse 1.083239, time use 0.138s
# *** epoch41, train loss 0.01436418, train rmse 1.6226, val loss 0.04167298, val rmse 1.084276, time use 0.139s
# *** epoch42, train loss 0.01474621, train rmse 1.6426, val loss 0.04136973, val rmse 1.072317, time use 0.125s
# *** epoch43, train loss 0.01386645, train rmse 1.5854, val loss 0.04426985, val rmse 1.084480, time use 0.138s
# *** epoch44, train loss 0.01302690, train rmse 1.5428, val loss 0.03827315, val rmse 1.029864, time use 0.140s
# *** epoch45, train loss 0.01393985, train rmse 1.5932, val loss 0.04102274, val rmse 1.065022, time use 0.149s
# *** epoch46, train loss 0.01415011, train rmse 1.6182, val loss 0.03230733, val rmse 1.018424, time use 0.138s
# *** epoch47, train loss 0.01361512, train rmse 1.5714, val loss 0.04193029, val rmse 1.071210, time use 0.142s
# *** epoch48, train loss 0.01365309, train rmse 1.5858, val loss 0.04653479, val rmse 1.123104, time use 0.135s
# *** epoch49, train loss 0.01420754, train rmse 1.5967, val loss 0.03682267, val rmse 1.034581, time use 0.136s
# *** epoch50, train loss 0.01421108, train rmse 1.6193, val loss 0.03652283, val rmse 1.031893, time use 0.142s
# *** epoch51, train loss 0.01373226, train rmse 1.5740, val loss 0.04018174, val rmse 1.071020, time use 0.165s
# *** epoch52, train loss 0.01363137, train rmse 1.5798, val loss 0.03560374, val rmse 1.038832, time use 0.132s
# *** epoch53, train loss 0.01345339, train rmse 1.5757, val loss 0.04261700, val rmse 1.072355, time use 0.134s
# *** epoch54, train loss 0.01325997, train rmse 1.5623, val loss 0.04032852, val rmse 1.035701, time use 0.127s
# *** epoch55, train loss 0.01355000, train rmse 1.5656, val loss 0.03829904, val rmse 1.022125, time use 0.146s
# *** epoch56, train loss 0.01315872, train rmse 1.5471, val loss 0.03623082, val rmse 1.007223, time use 0.141s
# *** epoch57, train loss 0.01327752, train rmse 1.5679, val loss 0.03523575, val rmse 1.001500, time use 0.134s
# *** epoch58, train loss 0.01377129, train rmse 1.5858, val loss 0.03769660, val rmse 1.016308, time use 0.135s
# *** epoch59, train loss 0.01368731, train rmse 1.5849, val loss 0.03674162, val rmse 1.024428, time use 0.138s
# *** epoch60, train loss 0.01295507, train rmse 1.5443, val loss 0.04056136, val rmse 1.028839, time use 0.140s
# *** epoch61, train loss 0.01336263, train rmse 1.5587, val loss 0.03933199, val rmse 1.007453, time use 0.160s
# *** epoch62, train loss 0.01367982, train rmse 1.5744, val loss 0.04139385, val rmse 1.053258, time use 0.132s
# *** epoch63, train loss 0.01347761, train rmse 1.5779, val loss 0.03610221, val rmse 1.014584, time use 0.138s
# *** epoch64, train loss 0.01307394, train rmse 1.5481, val loss 0.04802064, val rmse 1.109925, time use 0.126s
# *** epoch65, train loss 0.01390851, train rmse 1.5928, val loss 0.04254961, val rmse 1.033964, time use 0.141s
# *** epoch66, train loss 0.01355803, train rmse 1.5780, val loss 0.03762866, val rmse 1.015760, time use 0.166s
# *** epoch67, train loss 0.01305450, train rmse 1.5503, val loss 0.03666145, val rmse 0.999635, time use 0.141s
# *** epoch68, train loss 0.01367827, train rmse 1.5682, val loss 0.04101771, val rmse 1.046782, time use 0.136s
# *** epoch69, train loss 0.01288062, train rmse 1.5248, val loss 0.03875075, val rmse 1.043777, time use 0.140s
# *** epoch70, train loss 0.01323154, train rmse 1.5596, val loss 0.04203547, val rmse 1.092616, time use 0.165s
# *** epoch71, train loss 0.01329624, train rmse 1.5487, val loss 0.03897945, val rmse 1.061447, time use 0.133s
# *** epoch72, train loss 0.01316631, train rmse 1.5575, val loss 0.03726023, val rmse 1.054825, time use 0.143s
# *** epoch73, train loss 0.01259302, train rmse 1.5146, val loss 0.03955632, val rmse 1.059606, time use 0.143s
# *** epoch74, train loss 0.01317901, train rmse 1.5579, val loss 0.03384990, val rmse 1.015263, time use 0.152s
# *** epoch75, train loss 0.01384382, train rmse 1.5789, val loss 0.04784386, val rmse 1.147479, time use 0.154s
# *** epoch76, train loss 0.01364520, train rmse 1.5693, val loss 0.04601232, val rmse 1.133005, time use 0.135s
# *** epoch77, train loss 0.01384898, train rmse 1.5890, val loss 0.03668247, val rmse 1.047738, time use 0.132s
# *** epoch78, train loss 0.01278038, train rmse 1.5317, val loss 0.04019999, val rmse 1.064889, time use 0.164s
# *** epoch79, train loss 0.01305032, train rmse 1.5472, val loss 0.03410144, val rmse 1.010839, time use 0.155s
# *** epoch80, train loss 0.01338375, train rmse 1.5601, val loss 0.04399695, val rmse 1.080225, time use 0.160s
#
# ****************************************
# Final result:
# Total time 11.43s
# Test result:
# Test RMSE: 2.1156738050232304    Test MAE: 1.7285808324813843    Test MAPE: 25.489583611488342

# %%
#RMSE和样本有关，RMSE大表示预测值和理论值的差值也大
visualization(train_loss_lst, val_loss_lst)
plot_metric(train_score_lst)

# %%
train_loader = Data.DataLoader(train_set, batch_size=1, shuffle=True, num_workers=4, drop_last=True)
val_loader = Data.DataLoader(val_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)
test_loader = Data.DataLoader(test_set, batch_size=1, shuffle=False, num_workers=4, drop_last=True)

# %%
def time_series_visualize(net,test_iter,denormalize_fn,num_epoch):
    net.eval()
    y_predict = []
    y_true = []
    for epoch in range(num_epoch):
        for x,y in test_iter:
            y_hat = denormalize_fn(net(x.to(device)).detach().cpu()).numpy()
            y = denormalize_fn(y)
            y_true.append(y.detach().numpy())
            y_predict.append(y_hat)
    y_predict = np.array(y_predict).squeeze()# epoch batch feature 28X3
    print("y_predict:",y_predict.shape)
    y_true = np.array(y_true).squeeze() # 28X3
    print("y_true:",y_true.shape)
    x1 = np.linspace(1,y_predict.shape[0],y_predict.shape[0])
    print("x1:",x1.shape)
    for j in range(y_predict.shape[-1]):    
        plt.plot(x1,y_predict[:,j],label='predict')
        plt.plot(x1,y_true[:,j],label='truth')
        plt.xlabel("time")
        plt.ylabel("wind")
        plt.legend()
        plt.show()
time_series_visualize(lstm,train_loader,WindData.denormalize,1)
# Out:
# y_predict: (295, 3)
# y_true: (295, 3)
# x1: (295,)

# %%
time_series_visualize(lstm,val_loader,WindData.denormalize,1)
# Out:
# y_predict: (55, 3)
# y_true: (55, 3)
# x1: (55,)

# %%
time_series_visualize(lstm,test_loader,WindData.denormalize,1)
# Out:
# y_predict: (28, 3)
# y_true: (28, 3)
# x1: (28,)
